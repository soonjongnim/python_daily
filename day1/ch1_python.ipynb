# %% [markdown]
# # 파이썬 프로그래밍

# %%
kor = 90
eng = 100

sum = kor + eng
avg = sum / 2

print('sum = ', sum)
print('avg = ', avg)
# Out:
# sum =  190
# avg =  95.0

# %%
variable = 123456        # 숫자
variable2 = '하나둘셋'   # 문자

print(variable)
type(variable)
# Out:
# 123456
# int

# %%
variable = variable2  # 타입이 달라도 자동으로 대입이 됨. 
                      # * python 변수뿐만 아니라 모두가 객체이기때문에

print(variable)
type(variable)
# Out:
# 하나둘셋
# str

# %%
# !asc = qaa
# Out:
# 'asc'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
@abc = aa
# Out:
#   File "<ipython-input-13-1ba2d283ea50>", line 1
#     @abc = aa
#          ^
# SyntaxError: invalid syntax

# %%
age = 100
Age = 200
age, Age
# Out:
# (100, 200)

# %%
a, b = 100, 200 
a, b
# Out:
# (100, 200)

# %%
a = 100 ; b = 200
a, b
# Out:
# (100, 200)

# %%
x = 20
x
# Out:
# 20

# %%
print(x)
# Out:
# 20

# %%
Computer = 'my computer'
Computer
# Out:
# 'my computer'

# %%
Computer = 123456
Computer
# Out:
# 123456

# %%
age, Age, x, Computer
# Out:
# (100, 200, 20, 123456)

# %%
Computer = 12.0
Computer
# Out:
# 12.0

# %%
my_age = 20
my_age
# Out:
# 20

# %%
# percent#aa = 100   ## 특수문자 사용 불가
# percent#aa
# percent%aa = 100
# percent%aa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-dc404c8f2a0b> in <module>
# ----> 1 percent#aa = 100
#       2 percent#aa
#
# NameError: name 'percent' is not defined

# %% [markdown]
# ### 숫자

# %%
i = 10
j = 100
k = -1000
i, j, k
# Out:
# (10, 100, -1000)

# %%
f = -3000.4
f
# Out:
# -3000.4

# %%
f =  0.0
f
# Out:
# 0.0

# %%
g = ...
g
# Out:
# ...

# %%
a = 3e3
b = 3e-3
a, b
# Out:
# (3000.0, 0.003)

# %%
type(1)
# Out:
# int

# %%
type(0.1)
# Out:
# float

# %%
type('aaa')
# Out:
# str

# %%
type(['a'])
# Out:
# list

# %%
type(('s'))
# Out:
# str

# %%
type(1e3)
# Out:
# float

# %%
type(('a','b'))
# Out:
# tuple

# %%
type((1,2))
# Out:
# tuple

# %%
type({1:1,2:2})
# Out:
# dict

# %%
1e3, 3.3333, 6/5
# Out:
# (1000.0, 3.3333, 1.2)

# %%
type(6/5)
# Out:
# float

# %% [markdown]
# # 문자열

# %%
# 문자열 리터럴
str1 = "안녕"
str2 = '안녕'
str1, str2
# Out:
# ('안녕', '안녕')

# %%
type(str1), type(str2)
# Out:
# (str, str)

# %%
str3 = '\nssssss\ndddddd\tcccc'
str3
# Out:
# '\nssssss\ndddddd\tcccc'

# %% [markdown]
# # 인덱스

# %%
x = 'i am happy'
x
# Out:
# 'i am happy'

# %%
x[0], x[1], x[2]
# Out:
# ('i', ' ', 'a')

# %%
x[-1]
# Out:
# 'y'

# %%
x[:]
# Out:
# 'i am happy'

# %%
x[0:-1]
# Out:
# 'i am happ'

# %%
x[-4:-1]
# Out:
# 'app'

# %%
x[-4:]
# Out:
# 'appy'

# %%
# 복소수 리터럴

"""복소수"""
a = 1 + 3j
type(a), a
# Out:
# (complex, (1+3j))

# %%
b = 4 - 3j
a+b
# Out:
# (5+0j)

# %%
b.real, b.imag
# Out:
# (4.0, -3.0)

# %%
# 실수형 리터럴

"""실수형"""
a = 1.2
b = 3e3
c = -0.2e-4
type(a), isinstance(a, float)
# Out:
# (float, True)

# %%
a.is_integer()
# Out:
# False

# %%
a, b, c
# Out:
# (1.2, 3000.0, -2e-05)

# %%
# 복합 연산자
x = 10
x += 1
x
# Out:
# 11

# %%
x -= 2
x
# Out:
# 9

# %%
x *= 2
x
# Out:
# 18

# %%
x /= 2  # 나누기(실수)
x
# Out:
# 9.0

# %%
x %= 2
x
# Out:
# 0.0

# %%
y = 3
y //= 2   # 몫
y
# Out:
# 1

# %%
4 % 2 # 나머지
# Out:
# 0

# %%
10.0 * 2
# Out:
# 20.0

# %%
10.4 / 2
# Out:
# 5.2

# %%
0.0 / 10
# Out:
# 0.0

# %%
10 / 0.0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-34-6b9eafcaf187> in <module>
# ----> 1 10 / 0.0
#
# ZeroDivisionError: float division by zero

# %%
3**3
# Out:
# 27

# %%
a = 2
a << 2
# Out:
# 8

# %%
a >> 2
# Out:
# 0

# %%
# 문자열 +,*
'호'*111
# Out:
# '호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호호'

# %%
'하'+'나'
# Out:
# '하나'

# %%
a = 'ek'
b = 'vr'
a+b
# Out:
# 'ekvr'

# %%
a + 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-4a11178a7412> in <module>
# ----> 1 a + 100
#
# TypeError: must be str, not int

# %%
a + str(100)
# Out:
# 'ek100'

# %%
a = '100'
100 * int(a)
# Out:
# 10000

# %%
name = '김수영'
a = '이름은 %s입니다.'%name
a
# Out:
# '이름은 김수영입니다.'

# %%
b = '이름은 '+ name +'입니다.2'
b
# Out:
# '이름은 김수영입니다.2'

# %%
# 논리곱 연산
not 1, not 0
# Out:
# (False, True)

# %%
1 and 0
# Out:
# 0

# %%
1 or 0
# Out:
# 1

# %%
1 and 1
# Out:
# 1

# %%
True, False
# Out:
# (True, False)

# %%
type(True), type(False)
# Out:
# (bool, bool)

# %% [markdown]
# # formatting

# %%
age = 12

pr = '이름은 %s이고, 나이는 %d 입니다.' %(name, age)
pr
# Out:
# '이름은 김수영이고, 나이는 12 입니다.'

# %%
pr2 = '이름은 {0}이고, 나이는 {1} 입니다.'.format(name, age)
pr2
# Out:
# '이름은 김수영이고, 나이는 12 입니다.'

# %%
year = 2016
event = 'Referendum'
f'Result of the {year} {event}'
# Out:
# 'Result of the 2016 Referendum'

# %%
yes_votes = 42_572_654
no_votes = 43_132_495
percentage = yes_votes / (yes_votes + no_votes)
'{:-9} YES votes {:2.2%}'.format(yes_votes, percentage)
# Out:
# ' 42572654 YES votes 49.67%'

# %% [markdown]
# # 문자열 객체

# %%
"abc".upper()  # 대문자로 변경
# Out:
# 'ABC'

# %%
'abceddDDDefsdasdSADASD'.swapcase()       # 소문자를 대문자로 대문자를 소문자로 변경
# Out:
# 'ABCEDDdddEFSDASDsadasd'

# %%
'adsdsdsd'.capitalize()   # 앞에 글자 대문자로 변경
# Out:
# 'Adsdsdsd'

# %%
'  dasdasd  sad  '.strip()   #양쪽 끝 공백 제거
# Out:
# 'dasdasd  sad'

# %%
'dasdasd  sad\n\t aaaa    '.strip()
# Out:
# 'dasdasd  sad\n\t aaaa'

# %%
' ㅇㅇㅇㅇㅇㄴㅇㄴㅁㅇ   '.lstrip()
# Out:
# 'ㅇㅇㅇㅇㅇㄴㅇㄴㅁㅇ   '

# %%
'   sadsadasdasd   '.rstrip()
# Out:
# '   sadsadasdasd'

# %%
'aaa  ssss'.replace('s', '1')
# Out:
# 'aaa  1111'

# %%
'asdfghd s'.find('s')
# Out:
# -1

# %%
'asdfghd s'.find('l')
# Out:
# -1

# %%
'asdfghd s'.find('s', -1)
# Out:
# 8

# %%
msg = ['a','b','c']
"-".join(msg)
# Out:
# 'a-b-c'

# %%
"010-1234-5678".split('-')
# Out:
# ['010', '1234', '5678']

# %%
year = 2020
month = 3
day = 5

print(year, month, day, sep="/", end="<br>")
# Out:
# 2020/3/5<br>

# %%
a = '안녕하세요.'
b = '반갑습니다.'

print(a)
print(b)
print(a, end='')
print(b)
# Out:
# 안녕하세요.
# 반갑습니다.
# 안녕하세요.반갑습니다.

# %%
# Null python에선 None으로 한다.
abc = ""
type(abc)
# Out:
# str

# %%
abc = None
type(abc)
# Out:
# NoneType

# %% [markdown]
# # 입력

# %%
st_inpt = input('입력해 주세요>>')
type(st_inpt), st_inpt
# Out:
# 입력해 주세요>>aas
# (str, 'aas')

# %%
a = input('첫 번째 숫자를 입력해주세요: ')
b = input('두 번째 숫자를 입력해주세요: ')
print('{0}+{1}={2}'.format(a,b,int(a)+int(b)))
# Out:
# 첫 번째 숫자를 입력해주세요: 100
# 두 번째 숫자를 입력해주세요: 200
# 100+200=300

# %%
inch = float(input('인치(inch)를 입력하세요. '))
cm = inch * 2.54
# cm = cm.format(".2f")
# cm
print('센티미터:', format(cm,'.2f'))
# Out:
# 인치(inch)를 입력하세요. 32.8
# 센티미터: 83.31

# %%
name = input('학생 이름을 입력하세요.')
kor = int(input('국어 성적을 입력하세요.'))
eng = int(input('영어 성적을 입력하세요.'))
math = int(input('수학 성적을 입력하세요.'))

sum = kor + eng + math
avg = sum / 3

print('이름: %s, 국어: %d, 영어: %d, 수학: %d, 평균: %.1f점' %(name, kor, eng, math, avg))
# Out:
# 학생 이름을 입력하세요.테스트
# 국어 성적을 입력하세요.90
# 영어 성적을 입력하세요.80
# 수학 성적을 입력하세요.90
# 이름: 테스트, 국어: 90, 영어: 80, 수학: 90, 평균: 86.7점

# %% [markdown]
# # 주석문

# %%
# 한줄 주석문

"""주석문 입니다.
    여러줄 주석문
"""
# Out:
# '주석문 입니다.\n    여러줄 주석문\n'

# %%
mystr = """ 독 스트링.....

ㄴㅁㅇㅁㄴㅇㅁㄴㅇ
ㅁㄴㅇㅁㄴㅇㅁㄴㅇ
이렇게도 사용 가능"""

type(mystr)
# Out:
# str

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
print.__doc__
# Out:
# "print(value, ..., sep=' ', end='\\n', file=sys.stdout, flush=False)\n\nPrints the values to a stream, or to sys.stdout by default.\nOptional keyword arguments:\nfile:  a file-like object (stream); defaults to the current sys.stdout.\nsep:   string inserted between values, default a space.\nend:   string appended after the last value, default a newline.\nflush: whether to forcibly flush the stream."

# %%
mystr.__doc__
# Out:
# "str(object='') -> str\nstr(bytes_or_buffer[, encoding[, errors]]) -> str\n\nCreate a new string object from the given object. If encoding or\nerrors is specified, then the object must expose a data buffer\nthat will be decoded using the given encoding and error handler.\nOtherwise, returns the result of object.__str__() (if defined)\nor repr(object).\nencoding defaults to sys.getdefaultencoding().\nerrors defaults to 'strict'."
